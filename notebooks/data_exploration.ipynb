# %%
import sys
from pathlib import Path

# Move up from notebooks/ → project root, then Python can see utils/
sys.path.insert(0, str(Path().resolve().parent))

from utils import *

# %%
import scanpy as sc

# %%
data_dir = "../data/raw/GSE249995_RAW/GSM7968797/"
sample_prefix = "GSM7968797_"

# Load with the prefix specified
adata = sc.read_10x_mtx(
    data_dir, 
    prefix=sample_prefix, 
    var_names='gene_symbols', 
    make_unique=True
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 5
#       1 data_dir = "../data/raw/GSE249995_RAW/GSM7968797/"
#       2 sample_prefix = "GSM7968797_"
#       3
#       4 # Load with the prefix specified
# ----> 5 adata = sc.read_10x_mtx(
#       6     data_dir,
#       7     prefix=sample_prefix,
#       8     var_names='gene_symbols',
#
#     [... skipping hidden 1 frame]
#
# File H:\Projects\scRNA-Seq\RetinoblastomaAtlas\.venv\Lib\site-packages\scanpy\readwrite.py:590, in read_10x_mtx(path, var_names, make_unique, cache, cache_compression, gex_only, prefix, compressed)
#     587 with warnings.catch_warnings():
#     588     # this will be thrown below in “adata[:, ...].copy()”
#     589     warnings.filterwarnings("ignore", r".*names are not unique", UserWarning)
# --> 590     adata = _read_10x_mtx(
#     591         path,
# ...
